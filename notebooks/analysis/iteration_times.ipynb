# %%
import os, sys
sys.path.insert(1, os.path.join(os.getcwd()  , '../..'))

# %%
# imports
import random
import multiprocessing as mp
from collections import defaultdict
from core import * 
import plotly.graph_objects as go

# %%
possible_items = [
    TwoDimensionalItem(300, 400),
    TwoDimensionalItem(600, 300),
    TwoDimensionalItem(600, 400),
    TwoDimensionalItem(300, 200),
]

vehicle = Vehicle(
    compartments=[
        TwoDimensionalCompartment(800, 300),
        TwoDimensionalCompartment(800, 300),
        TwoDimensionalCompartment(800, 300),
        TwoDimensionalCompartment(800, 300),
        TwoDimensionalCompartment(800, 600),
        TwoDimensionalCompartment(800, 600),
    ]
)

# %%
# Define some problems

# Problem 1
nb_items_1 = 15
V_1 = list(range(0, nb_items_1 * 2 + 1)) 
random.seed(0)
items_1 = random.choices(possible_items, k=nb_items_1)
random.seed(0)
distance_matrix_1 = [
    [random.randint(1, 100) if i != 0 and j!=0 and i != j else 0 for i in V_1]
    for j in V_1
]
problem_1 = TwoDimensionalProblem(items_1, vehicle, distance_matrix_1)

# Problem 2
nb_items_2 = 15
V_2 = list(range(0, nb_items_2 * 2 + 1)) 
random.seed(100)
items_2 = random.choices(possible_items, k=nb_items_2)
random.seed(100)
distance_matrix_2 = [
    [random.randint(1, 100) if i != 0 and j!=0 and i != j else 0 for i in V_2]
    for j in V_2
]
problem_2 = TwoDimensionalProblem(items_2, vehicle, distance_matrix_2)

# %%
# Initial solutions for the problem by running the gurobi solver
initial_solution_time_limit = 1 # 1 second

# Problem 1                 
modelled_problem_1 = ModelledTwoDimensionalProblem(items_1, vehicle)
modelled_problem_1.create_model()
modelled_problem_1.apply_constraints()
modelled_problem_1.set_model_objective()
modelled_problem_1.solve(time_limit=initial_solution_time_limit)
initial_solution_1 = modelled_problem_1.extract_solution()

# Problem 2                 
modelled_problem_2 = ModelledTwoDimensionalProblem(items_2, vehicle)
modelled_problem_2.create_model()
modelled_problem_2.apply_constraints()
modelled_problem_2.set_model_objective()
modelled_problem_2.solve(time_limit=initial_solution_time_limit)
initial_solution_2 = modelled_problem_2.extract_solution()

initial_solutions_dict = {
    problem_1: initial_solution_1,
    problem_2: initial_solution_2,
}
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-05-14
# Set parameter TimeLimit to value 1
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 12819 rows, 1469 columns and 61479 nonzeros
# Model fingerprint: 0xf772a26f
# Variable types: 0 continuous, 1469 integer (1252 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 1255 rows and 298 columns
# Presolve time: 0.19s
# Presolved: 11564 rows, 1171 columns, 43492 nonzeros
# Variable types: 0 continuous, 1171 integer (961 binary)
# Found heuristic solution: objective 1159.0000000
#
# Root relaxation: objective 1.397000e+02, 522 iterations, 0.06 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  139.70000    0   28 1159.00000  139.70000  87.9%     -    0s
#      0     0  143.31111    0  155 1159.00000  143.31111  87.6%     -    0s
#      0     0  143.33898    0  144 1159.00000  143.33898  87.6%     -    0s
#      0     0          -    0      1159.00000  144.46247  87.5%     -    1s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 22
#   Lift-and-project: 4
#   Cover: 1
#   Implied bound: 5
#   MIR: 25
#   StrongCG: 1
#   Mod-K: 1
#   RLT: 4
#   Relax-and-lift: 11
#   BQP: 1
#
# Explored 1 nodes (1483 simplex iterations) in 1.01 seconds (0.75 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 1159
#
# Time limit reached
# Best objective 1.159000000000e+03, best bound 1.450000000000e+02, gap 87.4892%
# Set parameter TimeLimit to value 1
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 12819 rows, 1469 columns and 61479 nonzeros
# Model fingerprint: 0xfa2a85d2
# Variable types: 0 continuous, 1469 integer (1252 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 1254 rows and 297 columns
# Presolve time: 0.18s
# Presolved: 11565 rows, 1172 columns, 43494 nonzeros
# Variable types: 0 continuous, 1172 integer (962 binary)
# Found heuristic solution: objective 1126.0000000
#
# Root relaxation: objective 1.393333e+02, 433 iterations, 0.06 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  139.33333    0   35 1126.00000  139.33333  87.6%     -    0s
#      0     0  143.40586    0  128 1126.00000  143.40586  87.3%     -    0s
#      0     0  143.43324    0  129 1126.00000  143.43324  87.3%     -    0s
#      0     0  143.43324    0  130 1126.00000  143.43324  87.3%     -    0s
#      0     0  144.08621    0  158 1126.00000  144.08621  87.2%     -    0s
#      0     0  144.08621    0  165 1126.00000  144.08621  87.2%     -    0s
#
# Cutting planes:
#   Learned: 3
#   Gomory: 3
#   Cover: 4
#   Implied bound: 7
#   MIR: 21
#   StrongCG: 2
#   Zero half: 1
#   RLT: 2
#   Relax-and-lift: 6
#
# Explored 1 nodes (1060 simplex iterations) in 1.01 seconds (0.72 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 1126
#
# Time limit reached
# Best objective 1.126000000000e+03, best bound 1.450000000000e+02, gap 87.1226%

# %%
# Analyze how parallelism affects PLNS by using different numbers of processes
# across runs and degrees of destructions. For each run, fix the degree of 
# destruction (to fix expected computation per search iteration).
nb_cpus = mp.cpu_count()
nb_processes = list(range(1, nb_cpus)) # max nb_cpus - 1
time_limit = 20
destruction_degree_limits = [0.15, 0.2, 0.3] # to get 2, 3, 4 destruction degrees

# %%
from typing import Any, List, Dict

def get_solver_stats_per_process(
    problem: TwoDimensionalProblem, 
    initial_solution: Solution,
    nb_processes_list: List[int], 
    time_limit: float,
    min_degree_percent: float,
    max_degree_percent: float, 
) -> Dict[int, List[Dict[str, Any]]]:
    problem_results = dict()
    
    for nb_proc in nb_processes_list:
        # initialize a solver with the time limit and the number of process
        # for problem 1 with the initial solution of the gurobi solver
        solver = PLNS(
            problem, 
            initial_solution, 
            time_limit=time_limit, 
            nb_processes=nb_proc,
            min_destruction_degree=min_degree_percent,
            max_destruction_degree=max_degree_percent
        )
        solver.set_destruction_degree_criterion(DestructionDegreeCriterion.CONSTANT)
        solver.search()
        problem_results[nb_proc] = [solver.stats]
    
    return problem_results

# %%
# Problem 1 & 2 with destruction degree 2 (0.15 % for 15 items)

nb_processes_to_solver_stats_dict_2 = defaultdict(list)

for problem, initial_solution in initial_solutions_dict.items():
    problem_results = get_solver_stats_per_process(
        problem, 
        initial_solution,
        nb_processes,
        time_limit,
        min_degree_percent=0.15,
        max_degree_percent=0.15,    
    )
    for nb_proc in nb_processes:
        nb_processes_to_solver_stats_dict_2[nb_proc].extend(problem_results[nb_proc])
# Out:
# Parallel LNS initialized with 1 processes
# Terminating LNS in 131 iterations and obj 288
# Parallel LNS terminating w/ objective 288 in 131 iterations in 20.052916765213013 secs
# Parallel LNS initialized with 2 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 110 iterations and obj 260
# Parallel LNS terminating w/ objective 260 in 110 iterations in 20.102165937423706 secs
# Parallel LNS initialized with 3 processes
# Terminating LNS in 111 iterations and obj 234
# Parallel LNS terminating w/ objective 234 in 111 iterations in 20.136448860168457 secs
# Parallel LNS initialized with 4 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 109 iterations and obj 285
# Parallel LNS terminating w/ objective 285 in 109 iterations in 20.12850570678711 secs
# Parallel LNS initialized with 5 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 114 iterations and obj 277
# Parallel LNS terminating w/ objective 277 in 114 iterations in 20.04880666732788 secs
# Parallel LNS initialized with 6 processes
# Terminating LNS in 108 iterations and obj 329
# Parallel LNS terminating w/ objective 329 in 108 iterations in 20.060594081878662 secs
# Parallel LNS initialized with 7 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 115 iterations and obj 321
# Parallel LNS terminating w/ objective 321 in 115 iterations in 20.04950976371765 secs
# Parallel LNS initialized with 8 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 120 iterations and obj 270
# Parallel LNS terminating w/ objective 270 in 120 iterations in 20.03166961669922 secs
# Parallel LNS initialized with 9 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 103 iterations and obj 310
# Parallel LNS terminating w/ objective 310 in 103 iterations in 20.12105894088745 secs
# Parallel LNS initialized with 10 processes
# Terminating LNS in 105 iterations and obj 319
# Parallel LNS terminating w/ objective 319 in 105 iterations in 20.052186727523804 secs
# Parallel LNS initialized with 11 processes
# Terminating LNS in 112 iterations and obj 285
# Parallel LNS terminating w/ objective 285 in 112 iterations in 20.108121633529663 secs
# Parallel LNS initialized with 1 processes
# Terminating LNS in 126 iterations and obj 296
# Parallel LNS terminating w/ objective 296 in 126 iterations in 20.082983255386353 secs
# Parallel LNS initialized with 2 processes
# Terminating LNS in 108 iterations and obj 303
# Parallel LNS terminating w/ objective 303 in 108 iterations in 20.225205898284912 secs
# Parallel LNS initialized with 3 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 123 iterations and obj 261
# Parallel LNS terminating w/ objective 261 in 123 iterations in 20.104488611221313 secs
# Parallel LNS initialized with 4 processes
# Terminating LNS in 117 iterations and obj 280
# Parallel LNS terminating w/ objective 280 in 117 iterations in 20.114660501480103 secs
# Parallel LNS initialized with 5 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 126 iterations and obj 328
# Parallel LNS terminating w/ objective 328 in 126 iterations in 20.143121004104614 secs
# Parallel LNS initialized with 6 processes
# Terminating LNS in 115 iterations and obj 298
# Parallel LNS terminating w/ objective 298 in 115 iterations in 20.137274980545044 secs
# Parallel LNS initialized with 7 processes
# Terminating LNS in 114 iterations and obj 423
# Parallel LNS terminating w/ objective 423 in 114 iterations in 20.042158126831055 secs
# Parallel LNS initialized with 8 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 118 iterations and obj 288
# Parallel LNS terminating w/ objective 288 in 118 iterations in 20.070690155029297 secs
# Parallel LNS initialized with 9 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 116 iterations and obj 313
# Parallel LNS terminating w/ objective 313 in 116 iterations in 20.024636030197144 secs
# Parallel LNS initialized with 10 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 104 iterations and obj 361
# Parallel LNS terminating w/ objective 361 in 104 iterations in 20.157858848571777 secs
# Parallel LNS initialized with 11 processes
# Terminating LNS in 111 iterations and obj 244
# Parallel LNS terminating w/ objective 244 in 111 iterations in 20.072260856628418 secs

# %%
# Get iterations time for every cached solution in solver stats
# for every solver stats (problem_1 and problem_2), for every process nb (1..11)

nb_processes_to_iteration_times_2 = {
    nb_proc: [
        sol.iteration_time
        for stats in solver_stats_list for sol in stats["cached_solutions"]
        if sol.iteration_time > 1e-5
    ] 
    for nb_proc, solver_stats_list in nb_processes_to_solver_stats_dict_2.items()
} 

# Box plot for iteration times per number of process for degree of destruction = 2
fig = go.Figure()
for nb_proc, times in nb_processes_to_iteration_times_2.items():
    fig.add_trace(go.Box(y=times, name=nb_proc))

fig.show()

# %%
# Repeat for destruction degree 3 (0.2 %)
# Problem 1 & 2 with destruction degree 3 (0.2 % for 15 items)

# Solve
nb_processes_to_solver_stats_dict_3 = defaultdict(list)
for problem, initial_solution in initial_solutions_dict.items():
    problem_results = get_solver_stats_per_process(
        problem, 
        initial_solution,
        nb_processes,
        time_limit,
        min_degree_percent=0.2,
        max_degree_percent=0.2,    
    )
    for nb_proc in nb_processes:
        nb_processes_to_solver_stats_dict_3[nb_proc].extend(problem_results[nb_proc])
# Out:
# Parallel LNS initialized with 1 processes
# Terminating LNS in 88 iterations and obj 284
# Parallel LNS terminating w/ objective 284 in 88 iterations in 20.148770809173584 secs
# Parallel LNS initialized with 2 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 80 iterations and obj 286
# Parallel LNS terminating w/ objective 286 in 80 iterations in 20.038261651992798 secs
# Parallel LNS initialized with 3 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 76 iterations and obj 256
# Parallel LNS terminating w/ objective 256 in 76 iterations in 20.168838500976562 secs
# Parallel LNS initialized with 4 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 69 iterations and obj 220
# Parallel LNS terminating w/ objective 220 in 69 iterations in 20.193018674850464 secs
# Parallel LNS initialized with 5 processes
# Terminating LNS in 53 iterations and obj 289
# Parallel LNS terminating w/ objective 289 in 53 iterations in 20.283463954925537 secs
# Parallel LNS initialized with 6 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 42 iterations and obj 290
# Parallel LNS terminating w/ objective 290 in 42 iterations in 20.021682739257812 secs
# Parallel LNS initialized with 7 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 45 iterations and obj 305
# Parallel LNS terminating w/ objective 305 in 45 iterations in 20.22750425338745 secs
# Parallel LNS initialized with 8 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 51 iterations and obj 247
# Parallel LNS terminating w/ objective 247 in 51 iterations in 20.06008505821228 secs
# Parallel LNS initialized with 9 processes
# Terminating LNS in 46 iterations and obj 286
# Parallel LNS terminating w/ objective 286 in 46 iterations in 20.104634761810303 secs
# Parallel LNS initialized with 10 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 49 iterations and obj 257
# Parallel LNS terminating w/ objective 257 in 49 iterations in 20.140033721923828 secs
# Parallel LNS initialized with 11 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 49 iterations and obj 228
# Parallel LNS terminating w/ objective 228 in 49 iterations in 20.165011405944824 secs
# Parallel LNS initialized with 1 processes
# Terminating LNS in 95 iterations and obj 301
# Parallel LNS terminating w/ objective 301 in 95 iterations in 20.114195823669434 secs
# Parallel LNS initialized with 2 processes
# Terminating LNS in 81 iterations and obj 258
# Parallel LNS terminating w/ objective 258 in 81 iterations in 20.002536058425903 secs
# Parallel LNS initialized with 3 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 62 iterations and obj 293
# Parallel LNS terminating w/ objective 293 in 62 iterations in 20.01344919204712 secs
# Parallel LNS initialized with 4 processes
# Terminating LNS in 64 iterations and obj 328
# Parallel LNS terminating w/ objective 328 in 64 iterations in 20.21713948249817 secs
# Parallel LNS initialized with 5 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 54 iterations and obj 292
# Parallel LNS terminating w/ objective 292 in 54 iterations in 20.191911697387695 secs
# Parallel LNS initialized with 6 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 48 iterations and obj 284
# Parallel LNS terminating w/ objective 284 in 48 iterations in 20.225115299224854 secs
# Parallel LNS initialized with 7 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 44 iterations and obj 254
# Parallel LNS terminating w/ objective 254 in 44 iterations in 20.187192916870117 secs
# Parallel LNS initialized with 8 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 44 iterations and obj 325
# Parallel LNS terminating w/ objective 325 in 44 iterations in 20.151175498962402 secs
# Parallel LNS initialized with 9 processes
# Terminating LNS in 49 iterations and obj 296
# Parallel LNS terminating w/ objective 296 in 49 iterations in 20.15195870399475 secs
# Parallel LNS initialized with 10 processes
# Terminating LNS in 47 iterations and obj 267
# Parallel LNS terminating w/ objective 267 in 47 iterations in 20.09087634086609 secs
# Parallel LNS initialized with 11 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 44 iterations and obj 294
# Parallel LNS terminating w/ objective 294 in 44 iterations in 20.071200370788574 secs

# %%
# Get stats and plot
# 
# Get iterations time for every cached solution in solver stats
# for every solver stats (problem_1 and problem_2), for every process nb (1..11)
nb_processes_to_iteration_times_3 = {
    nb_proc: [
        sol.iteration_time
        for stats in solver_stats_list for sol in stats["cached_solutions"]
        if sol.iteration_time > 1e-5
    ] 
    for nb_proc, solver_stats_list in nb_processes_to_solver_stats_dict_3.items()
} 

# Plot
fig = go.Figure()
for nb_proc, times in nb_processes_to_iteration_times_3.items():
    fig.add_trace(go.Box(y=times, name=nb_proc))

fig.show()

# %%
# Repeat for destruction degree 4 (0.3 %)
# Problem 1 & 2 with destruction degree 4 (0.3 % for 15 items)

# Solve
nb_processes_to_solver_stats_dict_4 = defaultdict(list)
for problem, initial_solution in initial_solutions_dict.items():
    problem_results = get_solver_stats_per_process(
        problem, 
        initial_solution,
        nb_processes,
        time_limit,
        min_degree_percent=0.3,
        max_degree_percent=0.3,    
    )
    for nb_proc in nb_processes:
        nb_processes_to_solver_stats_dict_4[nb_proc].extend(problem_results[nb_proc])
# Out:
# Parallel LNS initialized with 1 processes
# Terminating LNS in 68 iterations and obj 269
# Parallel LNS terminating w/ objective 269 in 68 iterations in 20.217440605163574 secs
# Parallel LNS initialized with 2 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 78 iterations and obj 266
# Parallel LNS terminating w/ objective 266 in 78 iterations in 20.158053398132324 secs
# Parallel LNS initialized with 3 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 58 iterations and obj 293
# Parallel LNS terminating w/ objective 293 in 58 iterations in 20.14935803413391 secs
# Parallel LNS initialized with 4 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 49 iterations and obj 272
# Parallel LNS terminating w/ objective 272 in 49 iterations in 20.229610443115234 secs
# Parallel LNS initialized with 5 processes
# Terminating LNS in 44 iterations and obj 276
# Parallel LNS terminating w/ objective 276 in 44 iterations in 20.397281646728516 secs
# Parallel LNS initialized with 6 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 39 iterations and obj 244
# Parallel LNS terminating w/ objective 244 in 39 iterations in 20.416770696640015 secs
# Parallel LNS initialized with 7 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 39 iterations and obj 282
# Parallel LNS terminating w/ objective 282 in 39 iterations in 20.14026951789856 secs
# Parallel LNS initialized with 8 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 35 iterations and obj 253
# Parallel LNS terminating w/ objective 253 in 35 iterations in 20.14754033088684 secs
# Parallel LNS initialized with 9 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 32 iterations and obj 272
# Parallel LNS terminating w/ objective 272 in 32 iterations in 20.165297031402588 secs
# Parallel LNS initialized with 10 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 28 iterations and obj 270
# Parallel LNS terminating w/ objective 270 in 28 iterations in 20.2858407497406 secs
# Parallel LNS initialized with 11 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 28 iterations and obj 281
# Parallel LNS terminating w/ objective 281 in 28 iterations in 20.000582218170166 secs
# Parallel LNS initialized with 1 processes
# Terminating LNS in 68 iterations and obj 287
# Parallel LNS terminating w/ objective 287 in 68 iterations in 20.189703702926636 secs
# Parallel LNS initialized with 2 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 68 iterations and obj 276
# Parallel LNS terminating w/ objective 276 in 68 iterations in 20.02353000640869 secs
# Parallel LNS initialized with 3 processes
# Terminating LNS in 55 iterations and obj 311
# Parallel LNS terminating w/ objective 311 in 55 iterations in 20.003706216812134 secs
# Parallel LNS initialized with 4 processes
# Terminating LNS in 43 iterations and obj 286
# Parallel LNS terminating w/ objective 286 in 43 iterations in 20.16629934310913 secs
# Parallel LNS initialized with 5 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 44 iterations and obj 279
# Parallel LNS terminating w/ objective 279 in 44 iterations in 20.150354146957397 secs
# Parallel LNS initialized with 6 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 45 iterations and obj 288
# Parallel LNS terminating w/ objective 288 in 45 iterations in 20.000634908676147 secs
# Parallel LNS initialized with 7 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 34 iterations and obj 303
# Parallel LNS terminating w/ objective 303 in 34 iterations in 20.298931121826172 secs
# Parallel LNS initialized with 8 processes
# Terminating LNS in 35 iterations and obj 273
# Parallel LNS terminating w/ objective 273 in 35 iterations in 20.086792707443237 secs
# Parallel LNS initialized with 9 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 29 iterations and obj 247
# Parallel LNS terminating w/ objective 247 in 29 iterations in 20.397945165634155 secs
# Parallel LNS initialized with 10 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 33 iterations and obj 270
# Parallel LNS terminating w/ objective 270 in 33 iterations in 20.316623210906982 secs
# Parallel LNS initialized with 11 processes
# Parallel LNS timed out, not all insertion orders could be tried.
# Terminating LNS in 29 iterations and obj 298
# Parallel LNS terminating w/ objective 298 in 29 iterations in 20.05207085609436 secs

# %%
# Get stats and plot
# 
# Get iterations time for every cached solution in solver stats
# for every solver stats (problem_1 and problem_2), for every process nb (1..11)
nb_processes_to_iteration_times_4 = {
    nb_proc: [
        sol.iteration_time
        for stats in solver_stats_list for sol in stats["cached_solutions"]
        if sol.iteration_time > 1e-5
    ] 
    for nb_proc, solver_stats_list in nb_processes_to_solver_stats_dict_4.items()
} 

# Plot
fig = go.Figure()
for nb_proc, times in nb_processes_to_iteration_times_4.items():
    fig.add_trace(go.Box(y=times, name=nb_proc))

fig.show()
