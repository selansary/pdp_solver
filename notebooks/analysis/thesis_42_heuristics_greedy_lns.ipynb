# %%
# pdp package path
import os, sys
sys.path.insert(1, os.path.join(os.getcwd()  , '../..'))

# imports
import random
from collections import defaultdict
from core import * 
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
## Define problems with sizes 10, 15, 20
# Each with an id 1, 2, 3, ... where (id // 3) * 5 + 10 = number of requests

possible_items = [
    TwoDimensionalItem(300, 400),
    TwoDimensionalItem(600, 300),
    TwoDimensionalItem(600, 400),
    TwoDimensionalItem(300, 200),
]

# 2 small compartments and 2 large compartments
small_vehicle = Vehicle(
    compartments=[
        TwoDimensionalCompartment(800, 300),
        TwoDimensionalCompartment(800, 300),
        TwoDimensionalCompartment(800, 600),
        TwoDimensionalCompartment(800, 600), 
    ]
)

# 3 small compartments and 2 large compartments
medium_vehicle = Vehicle(
    compartments=[
        TwoDimensionalCompartment(800, 300),
        TwoDimensionalCompartment(800, 300),
        TwoDimensionalCompartment(800, 300),
        TwoDimensionalCompartment(800, 600),
        TwoDimensionalCompartment(800, 600), 
    ]
)

# 3 small compartments and 3 large compartments
large_vehicle = Vehicle(
    compartments=[
        TwoDimensionalCompartment(800, 300),
        TwoDimensionalCompartment(800, 300),
        TwoDimensionalCompartment(800, 300),
        TwoDimensionalCompartment(800, 600),
        TwoDimensionalCompartment(800, 600),
        TwoDimensionalCompartment(800, 600),  
    ]
)

vehicles = [small_vehicle, medium_vehicle, large_vehicle]

group_size = 3
instance_sizes = [10, 15, 20]
problem_ids = list(range(group_size * len(instance_sizes)))

# create random problems with seed based on id!
problems = []
modelled_problems = []
for prob_id in problem_ids:
    instance_size_idx = prob_id // group_size
    instance_size = instance_sizes[instance_size_idx]
    nb_items = instance_size
    vehicle = vehicles[instance_size_idx]
    V = list(range(0, nb_items * 2 + 1))
    random.seed(prob_id)
    items = random.choices(possible_items, k=nb_items)
    random.seed(prob_id)
    distance_matrix = [
        [random.randint(1, 100) if i != 0 and j!=0 and i != j else 0 for i in V]
        for j in V
    ]
    
    problem = TwoDimensionalProblem(items, vehicle, distance_matrix, name=f"prob_{prob_id}")
    problems.append(problem)

    # Modellel Problem for time-limited gurobi
    modelled_problem = ModelledTwoDimensionalProblem(items, vehicle, distance_matrix=distance_matrix)
    modelled_problem.create_model()
    modelled_problem.apply_constraints()
    modelled_problem.set_model_objective()
    modelled_problems.append(modelled_problem)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-07-11

# %%
# Initial, quick solutions by gurobi
initial_solutions_dict = {}
for prob_id, problem in enumerate(modelled_problems):
    initial_solution_time_limit = (prob_id // 3) + 1 # 1 sec for 10, 2 for 15, 3 for 20  
    modelled_problem = modelled_problems[prob_id]
    modelled_problem.solve(time_limit=initial_solution_time_limit)
    initial_solutions_dict[prob_id] = modelled_problem.extract_solution()
# Out:
# Set parameter TimeLimit to value 1
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4127 rows, 680 columns and 19367 nonzeros
# Model fingerprint: 0x92cb04c1
# Variable types: 0 continuous, 680 integer (575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 570 rows and 154 columns
# Presolve time: 0.06s
# Presolved: 3557 rows, 526 columns, 13502 nonzeros
# Variable types: 0 continuous, 526 integer (426 binary)
# Found heuristic solution: objective 1028.0000000
#
# Root relaxation: objective 1.603000e+02, 347 iterations, 0.02 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  160.30000    0   27 1028.00000  160.30000  84.4%     -    0s
#      0     0  164.05263    0   76 1028.00000  164.05263  84.0%     -    0s
#      0     0  166.00000    0  104 1028.00000  166.00000  83.9%     -    0s
#      0     0  166.00000    0   95 1028.00000  166.00000  83.9%     -    0s
#      0     0  166.00000    0  100 1028.00000  166.00000  83.9%     -    0s
#      0     0  166.00000    0  100 1028.00000  166.00000  83.9%     -    0s
#      0     0  166.00000    0   52 1028.00000  166.00000  83.9%     -    0s
# H    0     0                     858.0000000  166.00000  80.7%     -    0s
#      0     0  166.00000    0   34  858.00000  166.00000  80.7%     -    0s
#      0     0  166.00000    0   40  858.00000  166.00000  80.7%     -    0s
#      0     0  166.00000    0   37  858.00000  166.00000  80.7%     -    0s
#      0     0  166.00000    0   41  858.00000  166.00000  80.7%     -    0s
#      0     0  166.00000    0   31  858.00000  166.00000  80.7%     -    0s
#      0     0  166.00000    0   31  858.00000  166.00000  80.7%     -    0s
#      0     0  166.00000    0   31  858.00000  166.00000  80.7%     -    0s
#      0     2  166.50000    0   31  858.00000  166.50000  80.6%     -    0s
# H   71    76                     788.0000000  166.55963  78.9%  69.4    1s
# H   75    76                     764.0000000  166.55963  78.2%  67.4    1s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 6
#   Lift-and-project: 1
#   Cover: 2
#   Implied bound: 10
#   MIR: 34
#   StrongCG: 2
#   RLT: 15
#   Relax-and-lift: 4
#
# Explored 79 nodes (6314 simplex iterations) in 1.01 seconds (0.73 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 764 788 858 1028
#
# Time limit reached
# Best objective 7.640000000000e+02, best bound 1.670000000000e+02, gap 78.1414%
# Set parameter TimeLimit to value 1
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4127 rows, 680 columns and 19367 nonzeros
# Model fingerprint: 0x75d75c7d
# Variable types: 0 continuous, 680 integer (575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 588 rows and 160 columns
# Presolve time: 0.05s
# Presolved: 3539 rows, 520 columns, 13150 nonzeros
# Variable types: 0 continuous, 520 integer (420 binary)
# Found heuristic solution: objective 949.0000000
#
# Root relaxation: objective 1.106711e+02, 276 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  110.67105    0   30  949.00000  110.67105  88.3%     -    0s
# H    0     0                     946.0000000  112.45000  88.1%     -    0s
#      0     0  116.50000    0   33  946.00000  116.50000  87.7%     -    0s
#      0     0  116.50000    0   25  946.00000  116.50000  87.7%     -    0s
#      0     0  117.55000    0   53  946.00000  117.55000  87.6%     -    0s
#      0     0  117.55131    0   86  946.00000  117.55131  87.6%     -    0s
#      0     0  117.55263    0   63  946.00000  117.55263  87.6%     -    0s
#      0     0  117.58430    0   83  946.00000  117.58430  87.6%     -    0s
#      0     0  117.60959    0   78  946.00000  117.60959  87.6%     -    0s
#      0     0  118.66588    0   95  946.00000  118.66588  87.5%     -    0s
#      0     0  118.69501    0   92  946.00000  118.69501  87.5%     -    0s
#      0     0  119.76667    0   82  946.00000  119.76667  87.3%     -    0s
#      0     0  119.76667    0   95  946.00000  119.76667  87.3%     -    0s
#      0     0  120.21053    0   73  946.00000  120.21053  87.3%     -    0s
#      0     0  120.26250    0   84  946.00000  120.26250  87.3%     -    0s
# H    0     0                     902.0000000  120.26250  86.7%     -    0s
#      0     0  120.81949    0   83  902.00000  120.81949  86.6%     -    0s
#      0     0  120.86053    0   87  902.00000  120.86053  86.6%     -    0s
#      0     0  121.10000    0   96  902.00000  121.10000  86.6%     -    0s
#      0     0  121.12500    0   96  902.00000  121.12500  86.6%     -    0s
# H    0     0                     682.0000000  121.46842  82.2%     -    0s
#      0     0  121.50000    0   96  682.00000  121.50000  82.2%     -    0s
#      0     0  121.50000    0   96  682.00000  121.50000  82.2%     -    0s
# H    0     0                     678.0000000  122.10000  82.0%     -    0s
# H    0     0                     612.0000000  122.10000  80.0%     -    0s
#      0     0  122.25658    0   76  612.00000  122.25658  80.0%     -    0s
#      0     0  122.25658    0   76  612.00000  122.25658  80.0%     -    0s
#      0     2  122.25658    0   74  612.00000  122.25658  80.0%     -    1s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 4
#   Cover: 1
#   Implied bound: 5
#   MIR: 21
#   StrongCG: 2
#   RLT: 3
#   Relax-and-lift: 8
#
# Explored 1 nodes (1741 simplex iterations) in 1.01 seconds (0.72 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 612 678 682 ... 949
#
# Time limit reached
# Best objective 6.120000000000e+02, best bound 1.230000000000e+02, gap 79.9020%
# Set parameter TimeLimit to value 1
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4127 rows, 680 columns and 19367 nonzeros
# Model fingerprint: 0xa6172577
# Variable types: 0 continuous, 680 integer (575 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 606 rows and 166 columns
# Presolve time: 0.04s
# Presolved: 3521 rows, 514 columns, 12798 nonzeros
# Variable types: 0 continuous, 514 integer (414 binary)
# Found heuristic solution: objective 967.0000000
#
# Root relaxation: objective 1.245000e+02, 246 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  124.50000    0   32  967.00000  124.50000  87.1%     -    0s
#      0     0  133.20000    0   38  967.00000  133.20000  86.2%     -    0s
#      0     0  136.98184    0  104  967.00000  136.98184  85.8%     -    0s
#      0     0  137.00000    0   57  967.00000  137.00000  85.8%     -    0s
#      0     0  137.00000    0   63  967.00000  137.00000  85.8%     -    0s
#      0     0  137.00000    0   72  967.00000  137.00000  85.8%     -    0s
#      0     0  137.00000    0   71  967.00000  137.00000  85.8%     -    0s
# H    0     0                     946.0000000  137.00000  85.5%     -    0s
#      0     0  137.00000    0   74  946.00000  137.00000  85.5%     -    0s
#      0     0  137.00000    0   74  946.00000  137.00000  85.5%     -    0s
#      0     0  137.00000    0   74  946.00000  137.00000  85.5%     -    0s
#      0     2  137.00000    0   73  946.00000  137.00000  85.5%     -    0s
# H   31    42                     918.0000000  137.17829  85.1%  73.1    0s
# H   41    42                     867.0000000  137.17829  84.2%  65.6    0s
# H   68    74                     727.0000000  137.17829  81.1%  62.0    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 2
#   Cover: 3
#   Implied bound: 11
#   MIR: 42
#   Zero half: 1
#   RLT: 12
#   Relax-and-lift: 4
#   BQP: 1
#
# Explored 193 nodes (11653 simplex iterations) in 1.01 seconds (0.92 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 727 867 918 ... 967
#
# Time limit reached
# Best objective 7.270000000000e+02, best bound 1.380000000000e+02, gap 81.0179%
# Set parameter TimeLimit to value 2
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10853 rows, 1392 columns and 52013 nonzeros
# Model fingerprint: 0x5bf1382f
# Variable types: 0 continuous, 1392 integer (1206 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 1074 rows and 266 columns
# Presolve time: 0.15s
# Presolved: 9779 rows, 1126 columns, 36427 nonzeros
# Variable types: 0 continuous, 1126 integer (946 binary)
# Found heuristic solution: objective 1348.0000000
#
# Root relaxation: objective 1.940000e+02, 579 iterations, 0.07 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  194.00000    0   47 1348.00000  194.00000  85.6%     -    0s
#      0     0  194.00000    0   92 1348.00000  194.00000  85.6%     -    0s
#      0     0  194.40833    0  104 1348.00000  194.40833  85.6%     -    0s
#      0     0  194.40833    0   49 1348.00000  194.40833  85.6%     -    0s
#      0     0  195.00000    0  128 1348.00000  195.00000  85.5%     -    1s
#      0     0  195.10000    0  126 1348.00000  195.10000  85.5%     -    1s
#      0     0  195.31667    0  126 1348.00000  195.31667  85.5%     -    1s
# H    0     0                    1327.0000000  195.31667  85.3%     -    1s
#      0     0  195.33333    0  133 1327.00000  195.33333  85.3%     -    1s
#      0     0  195.43333    0  154 1327.00000  195.43333  85.3%     -    1s
#      0     0  195.43333    0  169 1327.00000  195.43333  85.3%     -    1s
#      0     0  195.51111    0  174 1327.00000  195.51111  85.3%     -    1s
#      0     0  195.51111    0  163 1327.00000  195.51111  85.3%     -    1s
# H    0     0                    1076.0000000  195.51111  81.8%     -    1s
#      0     2  195.51111    0  151 1076.00000  195.51111  81.8%     -    2s
#
# Cutting planes:
#   Implied bound: 11
#   MIR: 26
#   StrongCG: 3
#   RLT: 11
#   Relax-and-lift: 6
#   BQP: 1
#
# Explored 1 nodes (3179 simplex iterations) in 2.02 seconds (1.58 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1076 1327 1348
#
# Time limit reached
# Best objective 1.076000000000e+03, best bound 1.960000000000e+02, gap 81.7844%
# Set parameter TimeLimit to value 2
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10853 rows, 1392 columns and 52013 nonzeros
# Model fingerprint: 0xf7c80980
# Variable types: 0 continuous, 1392 integer (1206 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 1067 rows and 262 columns
# Presolve time: 0.17s
# Presolved: 9786 rows, 1130 columns, 36560 nonzeros
# Variable types: 0 continuous, 1130 integer (950 binary)
# Found heuristic solution: objective 1376.0000000
#
# Root relaxation: objective 1.403083e+02, 729 iterations, 0.09 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  140.30833    0  118 1376.00000  140.30833  89.8%     -    0s
# H    0     0                    1364.0000000  140.30833  89.7%     -    0s
# H    0     0                    1314.0000000  141.10000  89.3%     -    0s
#      0     0  149.57006    0  135 1314.00000  149.57006  88.6%     -    0s
#      0     0  149.58623    0  140 1314.00000  149.58623  88.6%     -    0s
#      0     0  149.58623    0  142 1314.00000  149.58623  88.6%     -    0s
#      0     0  150.37931    0  172 1314.00000  150.37931  88.6%     -    1s
#      0     0  150.42373    0  170 1314.00000  150.42373  88.6%     -    1s
#      0     0  150.78261    0  138 1314.00000  150.78261  88.5%     -    1s
#      0     0  150.78261    0  148 1314.00000  150.78261  88.5%     -    1s
#      0     0  151.00000    0  144 1314.00000  151.00000  88.5%     -    1s
#      0     0  151.00000    0  138 1314.00000  151.00000  88.5%     -    1s
#      0     0  151.00000    0  141 1314.00000  151.00000  88.5%     -    1s
#      0     0  151.00000    0  134 1314.00000  151.00000  88.5%     -    1s
#      0     0  151.00000    0   96 1314.00000  151.00000  88.5%     -    2s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 2
#   Implied bound: 5
#   MIR: 46
#   StrongCG: 2
#   Zero half: 2
#   RLT: 11
#   Relax-and-lift: 3
#
# Explored 1 nodes (2771 simplex iterations) in 2.01 seconds (1.36 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1314 1364 1376
#
# Time limit reached
# Best objective 1.314000000000e+03, best bound 1.510000000000e+02, gap 88.5084%
# Set parameter TimeLimit to value 2
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10853 rows, 1392 columns and 52013 nonzeros
# Model fingerprint: 0x4126e154
# Variable types: 0 continuous, 1392 integer (1206 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 1095 rows and 272 columns
# Presolve time: 0.15s
# Presolved: 9758 rows, 1120 columns, 35790 nonzeros
# Variable types: 0 continuous, 1120 integer (940 binary)
# Found heuristic solution: objective 1568.0000000
#
# Root relaxation: objective 1.533333e+02, 773 iterations, 0.09 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  153.33333    0   93 1568.00000  153.33333  90.2%     -    0s
#      0     0  157.66667    0  120 1568.00000  157.66667  89.9%     -    0s
#      0     0  157.66667    0  117 1568.00000  157.66667  89.9%     -    0s
#      0     0  158.22222    0  154 1568.00000  158.22222  89.9%     -    0s
#      0     0  158.22222    0  154 1568.00000  158.22222  89.9%     -    0s
#      0     0  159.26895    0  150 1568.00000  159.26895  89.8%     -    1s
#      0     0  159.50000    0   74 1568.00000  159.50000  89.8%     -    1s
#      0     0  159.50000    0   69 1568.00000  159.50000  89.8%     -    1s
#      0     0  159.50000    0   62 1568.00000  159.50000  89.8%     -    1s
#      0     0  159.50000    0   61 1568.00000  159.50000  89.8%     -    1s
#      0     0  159.50000    0   54 1568.00000  159.50000  89.8%     -    1s
#      0     2  159.95454    0   52 1568.00000  159.95454  89.8%     -    1s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 5
#   Cover: 9
#   Implied bound: 16
#   MIR: 39
#   Zero half: 2
#   RLT: 11
#   Relax-and-lift: 19
#   BQP: 1
#
# Explored 24 nodes (5484 simplex iterations) in 2.01 seconds (1.73 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 1568
#
# Time limit reached
# Best objective 1.568000000000e+03, best bound 1.610000000000e+02, gap 89.7321%
# Set parameter TimeLimit to value 3
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22289 rows, 2354 columns and 107969 nonzeros
# Model fingerprint: 0x2861f2db
# Variable types: 0 continuous, 2354 integer (2067 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 1683 rows and 392 columns
# Presolve time: 0.56s
# Presolved: 20606 rows, 1962 columns, 77089 nonzeros
# Variable types: 0 continuous, 1962 integer (1682 binary)
# Found heuristic solution: objective 1871.0000000
#
# Root relaxation: objective 1.381500e+02, 1419 iterations, 0.46 seconds (0.46 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  138.15000    0  132 1871.00000  138.15000  92.6%     -    1s
# H    0     0                    1794.0000000  138.15000  92.3%     -    1s
#      0     0  140.00000    0  158 1794.00000  140.00000  92.2%     -    2s
#      0     0  140.00000    0   85 1794.00000  140.00000  92.2%     -    2s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 3
#   Cover: 2
#   Implied bound: 14
#   MIR: 39
#   StrongCG: 2
#   RLT: 7
#   Relax-and-lift: 4
#
# Explored 1 nodes (2434 simplex iterations) in 3.02 seconds (1.68 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 1794 1871
#
# Time limit reached
# Best objective 1.794000000000e+03, best bound 1.400000000000e+02, gap 92.1962%
# Set parameter TimeLimit to value 3
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22289 rows, 2354 columns and 107969 nonzeros
# Model fingerprint: 0xd96b6f19
# Variable types: 0 continuous, 2354 integer (2067 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 1707 rows and 398 columns
# Presolve time: 0.52s
# Presolved: 20582 rows, 1956 columns, 76087 nonzeros
# Variable types: 0 continuous, 1956 integer (1676 binary)
# Found heuristic solution: objective 2099.0000000
#
# Root relaxation: objective 1.696317e+02, 1661 iterations, 0.36 seconds (0.52 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  169.63167    0  153 2099.00000  169.63167  91.9%     -    1s
#      0     0  172.70000    0  136 2099.00000  172.70000  91.8%     -    1s
#      0     0  172.70000    0   96 2099.00000  172.70000  91.8%     -    1s
#      0     0  173.04583    0  241 2099.00000  173.04583  91.8%     -    2s
#      0     0  173.05093    0  269 2099.00000  173.05093  91.8%     -    2s
#      0     0  173.05093    0  269 2099.00000  173.05093  91.8%     -    2s
# H    0     0                    1937.0000000  173.05093  91.1%     -    3s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 4
#   Implied bound: 13
#   MIR: 43
#   Zero half: 1
#   RLT: 6
#   Relax-and-lift: 7
#   BQP: 1
#
# Explored 1 nodes (2936 simplex iterations) in 3.01 seconds (1.93 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 1937 2099
#
# Time limit reached
# Best objective 1.937000000000e+03, best bound 1.740000000000e+02, gap 91.0170%
# Set parameter TimeLimit to value 3
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22289 rows, 2354 columns and 107969 nonzeros
# Model fingerprint: 0x020c7cc7
# Variable types: 0 continuous, 2354 integer (2067 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 8e+02]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 1707 rows and 398 columns
# Presolve time: 0.53s
# Presolved: 20582 rows, 1956 columns, 76087 nonzeros
# Variable types: 0 continuous, 1956 integer (1676 binary)
# Found heuristic solution: objective 1988.0000000
#
# Root relaxation: objective 1.869445e+02, 1223 iterations, 0.26 seconds (0.29 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  186.94452    0  221 1988.00000  186.94452  90.6%     -    1s
# H    0     0                    1935.0000000  186.94452  90.3%     -    1s
#      0     0  196.04403    0  256 1935.00000  196.04403  89.9%     -    2s
#      0     0  196.04403    0  191 1935.00000  196.04403  89.9%     -    2s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 15
#   Cover: 1
#   Implied bound: 8
#   MIR: 67
#   StrongCG: 2
#   Zero half: 1
#   RLT: 3
#   Relax-and-lift: 8
#   BQP: 1
#
# Explored 1 nodes (2242 simplex iterations) in 3.03 seconds (1.66 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 1935 1988
#
# Time limit reached
# Best objective 1.935000000000e+03, best bound 1.970000000000e+02, gap 89.8191%

# %%
import time

# %%
def get_gap(exact_val, heuristic_val):
    zp = heuristic_val
    zd = exact_val

    return abs(zp - zd) / abs(zp)

# %%
# greedy solvers
greedy_solvers = [
    GreedySolver(problem)
    for problem in problems
]

greedy_solutions = []
greedy_stats = dict()
for prob_id, solver in enumerate(greedy_solvers):
    st_time = time.time()
    solution = solver.solve(nb_solutions=1)[0]
    delta = time.time() - st_time
    greedy_solutions.append(solution)

    greedy_stats[prob_id] = dict(solution=solution, delta=delta, objective=problems[prob_id].evaluate_solution(solution))

# %%
for prob_id in problem_ids:
    stat = greedy_stats[prob_id]
    print(f"Greedy Sol: id={prob_id}, obj={stat['objective']}, solving_time={'{:.2f}'.format(1e6*stat['delta'])}")
# Out:
# Greedy Sol: id=0, obj=408, solving_time=415.80
# Greedy Sol: id=1, obj=364, solving_time=297.55
# Greedy Sol: id=2, obj=533, solving_time=330.69
# Greedy Sol: id=3, obj=485, solving_time=666.38
# Greedy Sol: id=4, obj=517, solving_time=1707.32
# Greedy Sol: id=5, obj=468, solving_time=694.04
# Greedy Sol: id=6, obj=381, solving_time=900.03
# Greedy Sol: id=7, obj=432, solving_time=946.52
# Greedy Sol: id=8, obj=665, solving_time=1138.45

# %%
stat
# Out:
# {'solution': Solution(
#  	order=0, 1, 16, 11, 18, 2, 22, 31, 7, 8, 10, 14, 36, 15, 9, 34, 4, 19, 29, 38, 20, 6, 35, 21, 3, 26, 30, 40, 28, 39, 13, 24, 17, 12, 32, 5, 33, 37, 25, 23, 27,
#  	step: 0 vertex: 0 	0, 0, 0, 0, 0, 0
#  	step: 1 vertex: 1 	400, 0, 0, 0, 0, 0
#  	step: 2 vertex: 16 	800, 0, 0, 0, 0, 0
#  	step: 3 vertex: 11 	800, 600, 0, 0, 0, 0
#  	step: 4 vertex: 18 	800, 600, 600, 0, 0, 0
#  	step: 5 vertex: 2 	800, 800, 600, 0, 0, 0
#  	step: 6 vertex: 22 	800, 600, 600, 0, 0, 0
#  	step: 7 vertex: 31 	800, 0, 600, 0, 0, 0
#  	step: 8 vertex: 7 	800, 200, 600, 0, 0, 0
#  	step: 9 vertex: 8 	800, 600, 600, 0, 0, 0
#  	step: 10 vertex: 10 	800, 600, 600, 300, 0, 0
#  	step: 11 vertex: 14 	800, 800, 600, 300, 0, 0
#  	step: 12 vertex: 36 	400, 800, 600, 300, 0, 0
#  	step: 13 vertex: 15 	800, 800, 600, 300, 0, 0
#  	step: 14 vertex: 9 	800, 800, 600, 700, 0, 0
#  	step: 15 vertex: 34 	800, 600, 600, 700, 0, 0
#  	step: 16 vertex: 4 	800, 600, 600, 700, 400, 0
#  	step: 17 vertex: 19 	800, 600, 600, 700, 700, 0
#  	step: 18 vertex: 29 	800, 600, 600, 300, 700, 0
#  	step: 19 vertex: 38 	800, 600, 0, 300, 700, 0
#  	step: 20 vertex: 20 	800, 800, 0, 300, 700, 0
#  	step: 21 vertex: 6 	800, 800, 400, 300, 700, 0
#  	step: 22 vertex: 35 	400, 800, 400, 300, 700, 0
#  	step: 23 vertex: 21 	0, 800, 400, 300, 700, 0
#  	step: 24 vertex: 3 	400, 800, 400, 300, 700, 0
#  	step: 25 vertex: 26 	400, 800, 0, 300, 700, 0
#  	step: 26 vertex: 30 	400, 800, 0, 0, 700, 0
#  	step: 27 vertex: 40 	400, 600, 0, 0, 700, 0
#  	step: 28 vertex: 28 	400, 200, 0, 0, 700, 0
#  	step: 29 vertex: 39 	400, 200, 0, 0, 400, 0
#  	step: 30 vertex: 13 	800, 200, 0, 0, 400, 0
#  	step: 31 vertex: 24 	800, 200, 0, 0, 0, 0
#  	step: 32 vertex: 17 	800, 600, 0, 0, 0, 0
#  	step: 33 vertex: 12 	800, 600, 600, 0, 0, 0
#  	step: 34 vertex: 32 	800, 600, 0, 0, 0, 0
#  	step: 35 vertex: 5 	800, 600, 400, 0, 0, 0
#  	step: 36 vertex: 33 	400, 600, 400, 0, 0, 0
#  	step: 37 vertex: 37 	400, 200, 400, 0, 0, 0
#  	step: 38 vertex: 25 	400, 200, 0, 0, 0, 0
#  	step: 39 vertex: 23 	0, 200, 0, 0, 0, 0
#  	step: 40 vertex: 27 	0, 0, 0, 0, 0, 0
#  ),
#  'delta': 0.001138448715209961,
#  'objective': 665}

# %%
exact_objs = [194, 164, 199, 215, 189, 201, 193]
exact_times = [23.1, 24.65, 137.52, 365.29, 2678.30, 2127.43, 19502.54]
for prob_id in [0, 1, 2, 3, 4, 5, 6]:
    greedy_obj = greedy_stats[prob_id]["objective"]
    greedy_time = greedy_stats[prob_id]["delta"]
    exact_obj = exact_objs[prob_id]
    exact_time = exact_times[prob_id]
    gap = get_gap(exact_val=exact_obj, heuristic_val=greedy_obj) * 100
    speedup = (exact_time / greedy_time)
    print(f"for {prob_id} gap: {'{:.2f}'.format(gap)}, speedup: {'{:.2e}'.format(speedup)}")
# Out:
# for 0 gap: 52.45, speedup: 5.56e+04
# for 1 gap: 54.95, speedup: 8.28e+04
# for 2 gap: 62.66, speedup: 4.16e+05
# for 3 gap: 55.67, speedup: 5.48e+05
# for 4 gap: 63.44, speedup: 1.57e+06
# for 5 gap: 57.05, speedup: 3.07e+06
# for 6 gap: 49.34, speedup: 2.17e+07

# %%
lns_solvers = []
# time_limits = [10, 20, 30]
time_limits = [5, 30, 60]
for prob_id, problem in enumerate(problems):
    initial_solution = initial_solutions_dict[prob_id]
    time_limit = time_limits[prob_id // 3]
    solver = LNS(problem, initial_solution=initial_solution, time_limit=time_limit)
    lns_solvers.append(solver)

# %%
for solver in lns_solvers:
    solver.search()
# Out:
# Terminating LNS in 155 iterations
# Total time: 5.02 Best objective: 255 found in 133 iterations in 4.34 s
#
# Terminating LNS in 192 iterations
# Total time: 5.01 Best objective: 213 found in 52 iterations in 1.36 s
#
# Terminating LNS in 188 iterations
# Total time: 5.01 Best objective: 258 found in 45 iterations in 1.26 s
#
# Terminating LNS in 225 iterations
# Total time: 30.06 Best objective: 303 found in 131 iterations in 17.73 s
#
# Terminating LNS in 244 iterations
# Total time: 30.10 Best objective: 260 found in 24 iterations in 3.72 s
#
# Terminating LNS in 209 iterations
# Total time: 30.03 Best objective: 269 found in 77 iterations in 11.79 s
#
# Terminating LNS in 115 iterations
# Total time: 60.12 Best objective: 349 found in 114 iterations in 59.59 s
#
# Terminating LNS in 120 iterations
# Total time: 60.00 Best objective: 251 found in 59 iterations in 30.02 s
#
# Terminating LNS in 119 iterations
# Total time: 60.17 Best objective: 399 found in 90 iterations in 46.43 s

# %%
lns_solvers_2 = []
time_limits = [5, 30, 100]
for prob_id, problem in enumerate(problems):
    if prob_id < 6:
        continue
    initial_solution = initial_solutions_dict[prob_id]
    time_limit = time_limits[prob_id // 3]
    solver = LNS(problem, initial_solution=initial_solution, time_limit=time_limit)
    lns_solvers_2.append(solver)

# %%
for solver in lns_solvers_2:
    solver.search()
# Out:
# Terminating LNS in 200 iterations
# Total time: 100.09 Best objective: 259 found in 66 iterations in 34.86 s
#
# Terminating LNS in 210 iterations
# Total time: 100.40 Best objective: 298 found in 200 iterations in 95.90 s
#
# Terminating LNS in 212 iterations
# Total time: 100.31 Best objective: 361 found in 154 iterations in 73.56 s

# %%
def get_best_before(max_time, solver_solutions):
    best_before = solver_solutions[1]
    for sol in solver_solutions:
        if sol.time_to_find <= max_time:
            if not best_before or sol.objective < best_before.objective:
                best_before = sol
        else:
            break
    return best_before


time_cutoff = 10
solutions_cutoff_dict = {}
for prob_id, solver in enumerate(lns_solvers):
    sol = get_best_before(time_cutoff, solver.solutions_cache)
    solutions_cutoff_dict[prob_id] = dict(solution=sol, objective=sol.objective)
    print(f"LNS cutoff Sol: id={prob_id}, obj={sol.objective}, solving_time={'{:.2f}'.format(sol.time_to_find)}")
# Out:
# LNS cutoff Sol: id=0, obj=255, solving_time=4.34
# LNS cutoff Sol: id=1, obj=213, solving_time=1.36
# LNS cutoff Sol: id=2, obj=258, solving_time=1.26
# LNS cutoff Sol: id=3, obj=310, solving_time=8.27
# LNS cutoff Sol: id=4, obj=260, solving_time=3.72
# LNS cutoff Sol: id=5, obj=291, solving_time=8.15
# LNS cutoff Sol: id=6, obj=451, solving_time=6.38
# LNS cutoff Sol: id=7, obj=416, solving_time=8.84
# LNS cutoff Sol: id=8, obj=470, solving_time=9.31

# %%
exact_objs = [194, 164, 199, 215, 189, 201, 193]
exact_times = [23.1, 24.65, 137.52, 365.29, 2678.30, 2127.43, 19502.54]
for prob_id in [0, 1, 2, 3, 4, 5, 6]:
    solver = lns_solvers[prob_id]
    lns_obj = solver.best_cached_solution.objective
    lns_time = solver.best_cached_solution.time_to_find
    lns_timelimit = solver.time_limit
    exact_obj = exact_objs[prob_id]
    exact_time = exact_times[prob_id]
    gap = get_gap(exact_val=exact_obj, heuristic_val=lns_obj) * 100
    speedup_best = (exact_time / lns_time)
    speedup_limit = (exact_time / lns_timelimit)
    print(f"for {prob_id} gap: {'{:.2f}'.format(gap)}, best speedup: {'{:.2e}'.format(speedup_best)}, limit speedup: {'{:.2e}'.format(speedup_limit)} ")
    # print(f"for {prob_id} gap: {gap}, speedup: {'{:.2e}'.format(speedup)}")
# Out:
# for 0 gap: 23.92, best speedup: 5.33e+00, limit speedup: 4.62e+00
# for 1 gap: 23.00, best speedup: 1.81e+01, limit speedup: 4.93e+00
# for 2 gap: 22.87, best speedup: 1.10e+02, limit speedup: 2.75e+01
# for 3 gap: 29.04, best speedup: 2.06e+01, limit speedup: 1.22e+01
# for 4 gap: 27.31, best speedup: 7.20e+02, limit speedup: 8.93e+01
# for 5 gap: 25.28, best speedup: 1.80e+02, limit speedup: 7.09e+01
# for 6 gap: 44.70, best speedup: 3.27e+02, limit speedup: 3.25e+02

# %%
exact_objs = [194, 164, 199, 215, 189, 201, 193]
exact_times = [23.1, 24.65, 137.52, 365.29, 2678.30, 2127.43, 19502.54]
for prob_id in [6]:
    solver = lns_solvers_2[prob_id - 6]
    lns_obj = solver.best_cached_solution.objective
    lns_time = solver.best_cached_solution.time_to_find
    lns_timelimit = solver.time_limit
    exact_obj = exact_objs[prob_id]
    exact_time = exact_times[prob_id]
    gap = get_gap(exact_val=exact_obj, heuristic_val=lns_obj) * 100
    speedup_best = (exact_time / lns_time)
    speedup_limit = (exact_time / lns_timelimit)
    print(f"for {prob_id} gap: {'{:.2f}'.format(gap)}, best speedup: {'{:.2e}'.format(speedup_best)}, limit speedup: {'{:.2e}'.format(speedup_limit)} ")
# Out:
# for 6 gap: 25.48, best speedup: 5.59e+02, limit speedup: 1.95e+02

# %%
exact_obj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-60050bc83aff> in <module>
# ----> 1 exact_obj
#
# NameError: name 'exact_obj' is not defined
